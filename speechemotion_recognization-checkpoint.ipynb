# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the DataSet

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk(r'C:\Users\yoges\OneDrive\Desktop\mpdataset\archive\TESS Toronto emotional speech set data'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
paths[:5]
# Out:
# ['C:\\Users\\yoges\\OneDrive\\Desktop\\mpdataset\\archive\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_back_angry.wav',
#  'C:\\Users\\yoges\\OneDrive\\Desktop\\mpdataset\\archive\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bar_angry.wav',
#  'C:\\Users\\yoges\\OneDrive\\Desktop\\mpdataset\\archive\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_base_angry.wav',
#  'C:\\Users\\yoges\\OneDrive\\Desktop\\mpdataset\\archive\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bath_angry.wav',
#  'C:\\Users\\yoges\\OneDrive\\Desktop\\mpdataset\\archive\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bean_angry.wav']

# %%
labels[:5]
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']

# %%
## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech  label
# 0  C:\Users\yoges\OneDrive\Desktop\mpdataset\arch...  angry
# 1  C:\Users\yoges\OneDrive\Desktop\mpdataset\arch...  angry
# 2  C:\Users\yoges\OneDrive\Desktop\mpdataset\arch...  angry
# 3  C:\Users\yoges\OneDrive\Desktop\mpdataset\arch...  angry
# 4  C:\Users\yoges\OneDrive\Desktop\mpdataset\arch...  angry

# %%
df['label'].value_counts()
# Out:
# label
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: count, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(data=df, x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(8,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(8,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Feauture Extraction

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-3.9698621e+02,  7.7440536e+01, -1.9592791e+01, -2.1666689e+01,
#        -2.1127560e+00,  1.0075363e+01, -2.0366707e+01, -6.0924492e+00,
#        -7.2122831e+00, -5.5736607e-01, -1.8325533e+00,  2.0210145e-01,
#         7.2755075e-01,  1.3177377e+00,  2.8863375e+00,  2.8557906e+00,
#        -4.7129216e+00, -4.4365110e+00, -1.6211596e+00, -1.0239839e+01,
#        -7.5512629e+00, -1.7968802e+00, -7.0376525e+00,  9.4365845e+00,
#         8.3558550e+00,  2.1712360e+01,  1.9216991e+01,  2.0348930e+01,
#         1.3413366e+01,  8.3391724e+00,  3.9472219e-01,  5.1113148e+00,
#         9.5687389e+00,  5.4548678e+00,  2.5099635e+00, -1.8239073e+00,
#         4.8689618e+00,  9.3139229e+00,  2.0891502e+00, -1.9064913e+00],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-396.9862, 77.44054, -19.59279, -21.666689, -...
# 1       [-465.73267, 98.77373, 0.6560086, -32.74544, -...
# 2       [-429.79196, 46.12401, 1.5550478, -0.21709459,...
# 3       [-403.46118, 76.32369, -12.531775, -22.288858,...
# 4       [-434.05756, 77.4455, 10.865501, 16.092943, 8....
#                               ...
# 2795    [-553.2201, 89.83577, 27.215466, 16.407124, 19...
# 2796    [-589.23676, 96.20407, 36.96118, 15.014446, 28...
# 2797    [-533.41815, 85.43242, 27.791998, 19.307178, 2...
# 2798    [-548.6142, 110.16424, 31.91024, 12.572518, 22...
# 2799    [-549.2962, 102.374565, 32.268833, 26.261614, ...
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %% [markdown]
# ## Create the LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 128)                 │               0 │
# ...

# %%
# Train the model
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
final_train_accuracy = history.history['accuracy'][-1] * 100
final_val_accuracy = history.history['val_accuracy'][-1] * 100

# Print the final accuracies in percentage format
print(f"Final Training Accuracy: {final_train_accuracy:.2f}%")
print(f"Final Validation Accuracy: {final_val_accuracy:.2f}%")
# Out:
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 153ms/step - accuracy: 0.4944 - loss: 1.3966 - val_accuracy: 0.6161 - val_loss: 0.7972
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.8323 - loss: 0.4301 - val_accuracy: 0.8518 - val_loss: 0.3479
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.9297 - loss: 0.2102 - val_accuracy: 0.9482 - val_loss: 0.1356
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.9432 - loss: 0.1733 - val_accuracy: 0.9446 - val_loss: 0.1511
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9581 - loss: 0.1395 - val_accuracy: 0.9643 - val_loss: 0.0908
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.9595 - loss: 0.1150 - val_accuracy: 0.9786 - val_loss: 0.0604
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.9780 - loss: 0.0891 - val_accuracy: 0.9643 - val_loss: 0.1143
# Epoch 8/50
# ...

# %% [markdown]
# ## Plot the results

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# Save the trained model
model.save('C:/Users/yoges/OneDrive/Desktop/mpdataset/traineddata/model.keras')

# %%
from tensorflow.keras.models import load_model
model = load_model('C:/Users/yoges/OneDrive/Desktop/mpdataset/traineddata/model.keras')

# %%
def predict_emotion(audio_path, model):
    # Extract MFCC features
    mfcc = extract_mfcc(audio_path)
    # Reshape for model input
    mfcc = np.expand_dims(mfcc, axis=0)
    mfcc = np.expand_dims(mfcc, axis=-1)
    # Predict probabilities
    predictions = model.predict(mfcc)
    # Get predicted label
    predicted_label = np.argmax(predictions)
    emotions = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'ps', 'sad']
    return emotions[predicted_label]

# %%
audio_path = r"C:\Users\yoges\OneDrive\Desktop\mpdataset\archive\TESS Toronto emotional speech set data\OAF_happy\OAF_bath_happy.wav"

# %%
predicted_emotion = predict_emotion(audio_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %%
print(f"The input audio is in '{predicted_emotion.upper()}' emotion.")
# Out:
# The input audio is in 'HAPPY' emotion.
